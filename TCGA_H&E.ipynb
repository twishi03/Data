# %% [markdown]
# <a href="https://colab.research.google.com/github/twishi03/Data/blob/main/TCGA_H%26E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: ! wget download data and displaye few images here https://zenodo.org/records/1214456/files/CRC-VAL-HE-7K.zip?download=1

# !wget https://zenodo.org/records/1214456/files/CRC-VAL-HE-7K.zip?download=1 -O CRC-VAL-HE-7K.zip

# !unzip CRC-VAL-HE-7K.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ACMSDEFF.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ACQQYLLS.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ADCHTGEE.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AFELDRPS.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AFFMDFQV.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AFQQTGKI.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AGKPYMDE.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AHDNMNIT.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AHKLPKMS.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AHQCDGMY.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AIIGEWYP.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ALLMHHRT.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ALQTIPLF.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-APHIEAQK.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-AQGAYQML.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ARHEISPN.tif
#   inflating: CRC-VAL-HE-7K/DEB/DEB-TCGA-ARIHITHS.tif
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Specify the directory containing the images
image_dir = 'CRC-VAL-HE-7K'  # Replace with the actual directory name if different

# Get a list of image files in the directory
image_files = [f for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f)) and f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]

# %%
# Display the first few images
num_images_to_display = 5 # Change to display more or less images
for i in range(min(num_images_to_display, len(image_files))):
  img = mpimg.imread(os.path.join(image_dir, image_files[i]))
  plt.figure()
  plt.imshow(img)
  plt.title(image_files[i])
  plt.axis('off')  # Hide the axes
  plt.show()

# %%
# prompt: read and display image /content/CRC-VAL-HE-7K/LYM/LYM-TCGA-AAWGSCHH.tif

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Assuming the image file exists at the specified path
image_path = '/content/CRC-VAL-HE-7K/NORM/NORM-TCGA-AERRFAKV.tif'

try:
  img = mpimg.imread(image_path)
  plt.figure(figsize=(8, 8))  # Adjust figure size if needed
  plt.imshow(img)
  plt.title(os.path.basename(image_path))
  plt.axis('off')
  plt.show()
except FileNotFoundError:
  print(f"Error: Image file not found at {image_path}")
except Exception as e:
  print(f"An error occurred: {e}")
